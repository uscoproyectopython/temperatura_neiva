# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Ruta al archivo XLSX en Google Drive (ajusta la ruta según tu ubicación)
file_path = "/content/drive/MyDrive/proyecto python/PoblationColab/GOVCO OSHU/Poblacion_Huila.xlsx"

# %%
# Cargar el archivo XLSX en un DataFrame de pandas
df = pd.read_excel(file_path) # DataFrame
df
# Out:
#         Código \nDANE Territorio   Año    Área Grupo de edad\n(quinquenio)  \
# 0               41001      Neiva  1995  Urbano                 00 a 4 años
# 1               41001      Neiva  1995  Urbano                 05 a 9 años
# 2               41001      Neiva  1995  Urbano                10 a 14 años
# 3               41001      Neiva  1995  Urbano                15 a 19 años
# 4               41001      Neiva  1995  Urbano                20 a 24 años
# ...               ...        ...   ...     ...                         ...
# 161308             41      Huila  2035   Total                60 a 64 años
# 161309             41      Huila  2035   Total                65 a 69 años
# 161310             41      Huila  2035   Total                70 a 74 años
# 161311             41      Huila  2035   Total                75 a 79 años
# 161312             41      Huila  2035   Total               80 y más años
#
#            Sexo  Población
# 0       Hombres      14241
# ...

# %%
df.keys()
# Out:
# Index(['Código \nDANE', 'Territorio', 'Año', 'Área',
#        'Grupo de edad\n(quinquenio)', 'Sexo', 'Población'],
#       dtype='object')

# %%
df = df.drop(['Código \nDANE'], axis=1) # Elimino las columnas
df
# Out:
#        Territorio   Año    Área Grupo de edad\n(quinquenio)     Sexo  \
# 0           Neiva  1995  Urbano                 00 a 4 años  Hombres
# 1           Neiva  1995  Urbano                 05 a 9 años  Hombres
# 2           Neiva  1995  Urbano                10 a 14 años  Hombres
# 3           Neiva  1995  Urbano                15 a 19 años  Hombres
# 4           Neiva  1995  Urbano                20 a 24 años  Hombres
# ...           ...   ...     ...                         ...      ...
# 161308      Huila  2035   Total                60 a 64 años    Total
# 161309      Huila  2035   Total                65 a 69 años    Total
# 161310      Huila  2035   Total                70 a 74 años    Total
# 161311      Huila  2035   Total                75 a 79 años    Total
# 161312      Huila  2035   Total               80 y más años    Total
#
#         Población
# 0           14241
# 1           13352
# 2           12801
# 3           11825
# 4           10365
# ...           ...
# ...

# %%
df.isnull() #Datos nulos del DataSet
# Out:
#         Territorio    Año   Área  Grupo de edad\n(quinquenio)   Sexo  \
# 0            False  False  False                        False  False
# 1            False  False  False                        False  False
# 2            False  False  False                        False  False
# 3            False  False  False                        False  False
# 4            False  False  False                        False  False
# ...            ...    ...    ...                          ...    ...
# 161308       False  False  False                        False  False
# 161309       False  False  False                        False  False
# 161310       False  False  False                        False  False
# 161311       False  False  False                        False  False
# 161312       False  False  False                        False  False
#
#         Población
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# ...

# %%
df.isnull().sum()#Datos nulos de las columnas del DataSet
# Out:
# Territorio                     0
# Año                            0
# Área                           0
# Grupo de edad\n(quinquenio)    0
# Sexo                           0
# Población                      0
# dtype: int64

# %%
df.dtypes #Tipo de datos del DataSet
# Out:
# Territorio                     object
# Año                             int64
# Área                           object
# Grupo de edad\n(quinquenio)    object
# Sexo                           object
# Población                       int64
# dtype: object

# %%
df.groupby(by=['Año']).size() #Calcular el tamaño de los grupos de la columna DataSet. ¿Cuántas filas?
# Out:
# Año
# 1993     153
# 1994     153
# 1995    3927
# 1996    3927
# 1997    3927
# 1998    3927
# 1999    3927
# 2000    3927
# 2001    3927
# 2002    3927
# 2003    3927
# 2004    3927
# 2005    3927
# 2006    3927
# 2007    3927
# 2008    3927
# 2009    3927
# 2010    3927
# 2011    3927
# 2012    3927
# 2013    3927
# 2014    3927
# 2015    3927
# 2016    3927
# 2017    3927
# 2018    3927
# 2019    3927
# 2020    3927
# 2021    3927
# 2022    3927
# 2023    3927
# 2024    3927
# 2025    3927
# 2026    3927
# 2027    3927
# 2028    3927
# 2029    3927
# 2030    3927
# 2031    3927
# 2032    3927
# 2033    3927
# 2034    3927
# 2035    3927
# dtype: int64

# %%
df.groupby(by=['Territorio']).size() #Calcular el tamaño de los grupos de la columna DataSet. ¿Cuántas filas?
# Out:
# Territorio
# Acevedo         4182
# Agrado          4182
# Aipe            4182
# Algeciras       4182
# Altamira        4182
# Baraya          4182
# Campoalegre     4182
# Colombia        4182
# Elías           4182
# Garzón          4182
# Gigante         4182
# Guadalupe       4182
# Hobo            4182
# Huila           6579
# Isnos           4182
# La Argentina    4182
# La Plata        4182
# Neiva           4182
# Nátaga          4182
# Oporapa         4182
# Paicol          4182
# Palermo         4182
# Palestina       4182
# Pital           4182
# Pitalito        4182
# Rivera          4182
# Saladoblanco    4182
# San Agustín     4182
# Santa María     4182
# Suaza           4182
# Tarqui          4182
# Tello           4182
# Teruel          4182
# Tesalia         4182
# Timaná          4182
# Villavieja      4182
# Yaguará         4182
# Íquira          4182
# dtype: int64

# %%
df.groupby(by=['Grupo de edad\n(quinquenio)']).size() #Calcular el tamaño de los grupos de la columna DataSet. ¿Cuántas filas?
# Out:
# Grupo de edad\n(quinquenio)
# 00 a 4 años      9489
# 05 a 9 años      9489
# 10 a 14 años     9489
# 15 a 19 años     9489
# 20 a 24 años     9489
# 25 a 29 años     9489
# 30 a 34 años     9489
# 35 a 39 años     9489
# 40 a 44 años     9489
# 45 a 49 años     9489
# 50 a 54 años     9489
# 55 a 59 años     9489
# 60 a 64 años     9489
# 65 a 69 años     9489
# 70 a 74 años     9489
# 75 a 79 años     9489
# 80 y más años    9489
# dtype: int64

# %%
df.groupby(by=['Sexo']).size() #Calcular el tamaño de los grupos de la columna DataSet. ¿Cuántas filas?
# Out:
# Sexo
# Hombres    79560
# Mujeres    79560
# Total       2193
# dtype: int64

# %%
df.drop(df[(df['Territorio'] != 'Neiva') | (df['Año'] >= 2023)].index, inplace=True) #Elimino filas que sean diferente de Neiva y años mayores = 2023
df
# Out:
#      Territorio   Año    Área Grupo de edad\n(quinquenio)     Sexo  Población
# 0         Neiva  1995  Urbano                 00 a 4 años  Hombres      14241
# 1         Neiva  1995  Urbano                 05 a 9 años  Hombres      13352
# 2         Neiva  1995  Urbano                10 a 14 años  Hombres      12801
# 3         Neiva  1995  Urbano                15 a 19 años  Hombres      11825
# 4         Neiva  1995  Urbano                20 a 24 años  Hombres      10365
# ...         ...   ...     ...                         ...      ...        ...
# 2851      Neiva  2022   Total                60 a 64 años  Mujeres       9756
# 2852      Neiva  2022   Total                65 a 69 años  Mujeres       7499
# 2853      Neiva  2022   Total                70 a 74 años  Mujeres       5389
# 2854      Neiva  2022   Total                75 a 79 años  Mujeres       3539
# 2855      Neiva  2022   Total               80 y más años  Mujeres       4251
#
# [2856 rows x 6 columns]

# %%
df['Territorio'].unique()
# Out:
# array(['Neiva'], dtype=object)

# %%
df['Año'].unique()
# Out:
# array([1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020, 2021, 2022])

# %%
#En las siguientes líneas vamos e buscar en la llave 'Año' el int(2023)
Buscar_Neiva= df.loc[:, 'Territorio'] == 'Neiva'
df.loc[Buscar_Neiva]
# Out:
#      Territorio   Año    Área Grupo de edad\n(quinquenio)     Sexo  Población
# 0         Neiva  1995  Urbano                 00 a 4 años  Hombres      14241
# 1         Neiva  1995  Urbano                 05 a 9 años  Hombres      13352
# 2         Neiva  1995  Urbano                10 a 14 años  Hombres      12801
# 3         Neiva  1995  Urbano                15 a 19 años  Hombres      11825
# 4         Neiva  1995  Urbano                20 a 24 años  Hombres      10365
# ...         ...   ...     ...                         ...      ...        ...
# 2851      Neiva  2022   Total                60 a 64 años  Mujeres       9756
# 2852      Neiva  2022   Total                65 a 69 años  Mujeres       7499
# 2853      Neiva  2022   Total                70 a 74 años  Mujeres       5389
# 2854      Neiva  2022   Total                75 a 79 años  Mujeres       3539
# 2855      Neiva  2022   Total               80 y más años  Mujeres       4251
#
# [2856 rows x 6 columns]

# %%
df.groupby(by=['Año']).sum()
# Out:
# <ipython-input-17-89cb9c47356e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by=['Año']).sum()
#       Población
# Año
# 1995     530882
# 1996     540398
# 1997     549782
# 1998     558718
# 1999     567366
# 2000     575824
# 2001     584100
# 2002     592072
# 2003     599730
# 2004     607266
# 2005     614730
# 2006     622258
# 2007     629820
# 2008     637322
# 2009     644878
# 2010     652438
# 2011     660044
# 2012     667434
# 2013     674904
# 2014     682464
# 2015     690132
# 2016     698096
# 2017     705998
# 2018     714784
# 2019     722098
# 2020     728816
# 2021     734800
# 2022     740636

# %%
df.
